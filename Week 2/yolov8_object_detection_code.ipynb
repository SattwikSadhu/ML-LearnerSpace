# %%
# !nvidia-smi
# Out:
# Tue Jul  9 10:37:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8               9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
from IPython.display import Image
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/78.2 GB disk)

# %%
# Drive mounted in colab through GUI

# %% [markdown]
# Training using yolov8s.pt upto 50 epochs (results in runs/detect/train and runs/detect/predict)

# %%
# %cd /content/drive/MyDrive/YOLOv8
# !yolo train model=yolov8s.pt data=/content/drive/MyDrive/YOLOv8/car/data.yaml epochs=50 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/YOLOv8

# %%
# !yolo predict model=/content/drive/MyDrive/YOLOv8/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/YOLOv8/car/test/images
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11131776 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 640x640 1 front_grill, 1 license_plate, 648.5ms
# image 2/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 640x640 1 car, 1 license_plate, 552.0ms
# image 3/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 640x640 3 cars, 1 door, 2 license_plates, 551.8ms
# image 4/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 640x640 1 front_grill, 2 headlamps, 1 license_plate, 528.7ms
# ...

# %%
Image('/content/drive/MyDrive/YOLOv8/runs/detect/train/confusion_matrix.png')

# %%
Image('/content/drive/MyDrive/YOLOv8/runs/detect/train/confusion_matrix_normalized.png')

# %%
Image('/content/drive/MyDrive/YOLOv8/runs/detect/train/results.png')

# %% [markdown]
# Training using runs/detect/train/weights/best.pt from 51 to 100 epochs (results in runs/detect/train2 and runs/detect/predict2)

# %%
# !yolo train model=/content/drive/MyDrive/YOLOv8/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/YOLOv8/car/data.yaml epochs=50 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# It's clear from the validation set that the features headlamp, taillamp, sideview_mirror and wheel are more difficult to train.

# %%
# !yolo predict model=/content/drive/MyDrive/YOLOv8/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/YOLOv8/car/test/images
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,776 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 640x640 1 car, 1 license_plate, 16.4ms
# image 2/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 640x640 1 car, 1 license_plate, 16.4ms
# image 3/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 640x640 3 cars, 1 headlamp, 2 license_plates, 16.5ms
# image 4/22 /content/drive/MyDrive/YOLOv8/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 640x640 1 car, 1 front_grill, 2 headlamps, 1 license_plate, 16.4ms
# ...

# %%
Image('/content/drive/MyDrive/YOLOv8/runs/detect/train2/confusion_matrix.png')

# %%
Image('/content/drive/MyDrive/YOLOv8/runs/detect/train2/confusion_matrix_normalized.png')

# %%
Image('/content/drive/MyDrive/YOLOv8/runs/detect/train2/results.png')
